# %%
import quantipy as qp
import pandas as pd
import datasmoothie
import io

# %%
dataset = qp.DataSet("my dataset", dimensions_comp=False)

# %% [markdown]
# ## Choose whether to read a file that you upload to data, or pull data from Datasmoothie

# %% [markdown]
# #### uncomment to read quantipy data

# %%
# dataset.read_quantipy('meta_data.json', 'data.csv')

# %% [markdown]
# #### or read from Datasmoothie

# %%
# parameters
client_api = "0f1b526cb2a85dd150db6ba6b3717b91d7863fd0" #demo account API key
datasource_id = 2477 # replace this with the integer id of your Datasmoothie datasource

# %%
client = datasmoothie.Client(api_key=client_api) #connect to the api

# %%
datasource = client.get_datasource(datasource_id) # fetch a Datasource object
meta_and_data = datasource.get_meta_and_data() # fetch the survey meta-data and data
dataset.from_components(pd.read_csv(io.StringIO(meta_and_data['data'])), #create a Quantipy dataset
                        meta_and_data['meta'])

# %% [markdown]
# # Start using Quantipy here
# #### data processing, weight, recode, merge, clean

# %%
# view variables
#dataset.variables()
dataset.crosstab('q1', 'gender', ci=['c%', 'counts'], sig_level=[0.05])
# Out:
# Question                                                                       gender. What is your gender?
# Values                                                                                                 Male Female
# Test-IDs                                                                                                  A      B
# Question                                Values
# q1. What is your main fitness activity? Base                                                         3952.0   4303
#                                         Other                                                          41.0     50
#                                                                                                         1.0    1.2
#                                         0.05                                                            NaN    NaN
#                                         Swimming                                                      145.0    152
#                                                                                                         3.7    3.5
#                                         0.05                                                            NaN    NaN
#                                         Running/jogging                                               205.0    192
#                                                                                                         5.2    4.5
#                                         0.05                                                            NaN    NaN
#                                         Lifting weights                                              1094.0   1204
#                                                                                                        27.7     28
#                                         0.05                                                            NaN    NaN
#                                         Aerobics                                                     1438.0   1561
#                                                                                                        36.4   36.3
#                                         0.05                                                            NaN    NaN
#                                         Yoga                                                           95.0     99
#                                                                                                         2.4    2.3
#                                         0.05                                                            NaN    NaN
#                                         Pilates                                                       199.0    278
#                                                                                                         5.0    6.5
#                                         0.05                                                            NaN      A
#                                         Football (soccer)                                             447.0    447
#                                                                                                        11.3   10.4
#                                         0.05                                                            NaN    NaN
#                                         Basketball                                                     65.0     66
#                                                                                                         1.6    1.5
#                                         0.05                                                            NaN    NaN
#                                         Hockey                                                          3.0      1
#                                                                                                         0.1      0
#                                         0.05                                                            NaN    NaN
#                                         I regularly change my fitness activity                         39.0     65
#                                                                                                         1.0    1.5
#                                         0.05                                                            NaN      A
#                                         Not applicable - I don't exercise                             181.0    188
#                                                                                                         4.6    4.4
#                                         0.05                                                            NaN    NaN

# %% [markdown]
# # Upload the result to Datasmoothie
# #### uncomment the line below and upload your result when you're done

# %%
# don't do this, as it is permanent :) but this is how it's done
#datasource.update_meta_and_data(dataset._meta, dataset.data().to_csv())
